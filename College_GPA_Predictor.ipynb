# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajeffries0613/Grand-Circus-Labs/blob/main/College_GPA_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install seaborn matplotlib statsmodels

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
df = pd.read_csv('college_gpa_predictor.csv')

# %%
df.head()
# Out:
#    sat_sum  fy_gpa
# 0     1270    3.18
# 1     1220    3.33
# 2     1160    3.25
# 3      950    2.42
# 4     1070    2.63

# %% [markdown]
# ### Scatterplot

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.scatterplot(x="sat_sum", y="fy_gpa", data=data, alpha=0.7)
plt.title('Scatter Plot of SAT Scores vs. College GPA')
plt.xlabel('SAT Total Score')
plt.ylabel('College GPA')
plt.show()

# %% [markdown]
# ### Linear Regression

# %%
x = data['sat_sum']
y = data['fy_gpa']
x = sm.add_constant(x)

model = sm.OLS(y, x).fit()

print=(model.summary())
